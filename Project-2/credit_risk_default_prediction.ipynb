# %% [markdown]
# # Credit Risk Default Prediction
# Run the full project using `src/train_model.py` or use this notebook for quick EDA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
application = pd.read_csv('data/application.csv')
bureau = pd.read_csv('data/bureau.csv')
previous_loans = pd.read_csv('data/previous_loans.csv')
payments = pd.read_csv('data/payments.csv')
credit_card = pd.read_csv('data/credit_card.csv')
train_labels = pd.read_csv('data/train_labels.csv')
test = pd.read_csv('data/test.csv')
print(application.shape, bureau.shape, previous_loans.shape, payments.shape, credit_card.shape, train_labels.shape, test.shape)

# %%
train_labels['default_12m'].value_counts(normalize=True) * 100

# %%
sns.countplot(x='default_12m', data=train_labels)
plt.title('Default Distribution')
plt.show()
